# %% [markdown]
# <a href="https://colab.research.google.com/github/Angga-Luri/dataset/blob/main/image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
from numpy import *
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib
import os

# %%
img_rows, img_cols = 224, 224

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path_dataset_type5 = '/content/gdrive/My Drive/UNUSIDA/data_val/type5'
path_dataset_preprocessing_type5 = '/content/gdrive/My Drive/UNUSIDA/data_val/type5'

# path_dataset_type2 = '/content/gdrive/My Drive/riset/dataset_train/type2'
# path_dataset_preprocessing_type2 = '/content/gdrive/My Drive/riset/data_train/type2'

# path_dataset_type3 = '/content/gdrive/My Drive/riset/dataset_train/type3'
# path_dataset_preprocessing_type3 = '/content/gdrive/My Drive/riset/data_train/type3'

# path_dataset_type4 = '/content/gdrive/My Drive/riset/dataset_train/type4'
# path_dataset_preprocessing_type4 = '/content/gdrive/My Drive/riset/data_train/type4'

# path_dataset_type5 = '/content/gdrive/My Drive/riset/dataset_train/type5'
# path_dataset_preprocessing_type5 = '/content/gdrive/My Drive/riset/data_train/type5'

# %%
listing5 = os.listdir(path_dataset_type5)
num_samples5=size(listing5)
print(listing5)
print(num_samples5)

# listing2 = os.listdir(path_dataset_type2)
# num_samples2=size(listing2)
# print(listing2)
# print(num_samples2)

# listing3 = os.listdir(path_dataset_type3)
# num_samples3=size(listing3)
# print(listing3)
# print(num_samples3)

# listing4 = os.listdir(path_dataset_type4)
# num_samples4=size(listing4)
# print(listing4)
# print(num_samples4)

# listing5 = os.listdir(path_dataset_type5)
# num_samples5=size(listing5)
# print(listing5)
# print(num_samples5)
# Out:
# ['5 (61).jpg', '5 (62).jpg', '5 (63).jpg', '5 (64).jpg', '5 (65).jpg', '5 (66).jpg', '5 (67).jpg', '5 (68).jpg', '5 (69).jpg', '5 (70).jpg', '5 (71).jpg', '5 (72).jpg', '5 (73).jpg', '5 (74).jpg', '5 (75).jpg', '5 (76).jpg', '5 (77).jpg', '5 (78).jpg', '5 (79).jpg', '5 (80).jpg']
# 20

# %%
import cv2
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

import cv2
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from PIL import Image
import os, sys


# start_row, start_col = int(180), int (1)
# end_row, end_col = int(500), int (800)
# up_width = 800
# up_height = 300
# up_points = (up_width, up_height)
resize = (224, 224)
# listingStr = len(listing1)
# listingInt = int(str(listingInt))
# print (str(listingInt))

for file in listing5:
    image = cv2.imread(path_dataset_type5+ '/' + file)
    # im = Image.open( path_dataset_try+ '/' + file)
    # image_scaled_up = cv2.resize(image, up_points, interpolation=cv2.INTER_LINEAR)
    # image_cropped = image_scaled_up[start_row:end_row, start_col:end_col]
    # img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # ret, image_thresh5 = cv2.threshold(img_gray, 100, 255, cv2.THRESH_TOZERO_INV)
    # image_resize = cv2.resize(image, resize, interpolation=cv2.INTER_LINEAR)
    img_gray2 = cv2.cvtColor(image_resize, cv2.COLOR_BGR2GRAY)
    cv2_imshow(img_gray2)
    # img = im.resize((img_rows,img_cols))
    # gray = image_resize.convert('L')
    # image_resize.save(path_dataset_try_dataset_pre +'/' +  file, "JPEG")
    # cv2.imwrite(path_dataset_try_dataset_pre +'/' +  file, "JPEG")
    isWritten = cv2.imwrite(path_dataset_preprocessing_type5+'/'+file, img_gray2)
    if isWritten:
      print('The image is successfully saved.')
    # print(image_resize)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FF237387BB0>
# The image is successfully saved.
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FF237387100>
# The image is successfully saved.
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FF237386680>
# The image is successfully saved.
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FF237387C40>
# The image is successfully saved.
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FF237386800>
# The image is successfully saved.
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FF237387610>
# The image is successfully saved.
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FF2373C8670>
# The image is successfully saved.
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FF237386FE0>
# The image is successfully saved.
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FF2373C8820>
# The image is successfully saved.
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FF237386590>
# ...
